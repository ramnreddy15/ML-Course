# %%
#
import torch
import torch.nn as nn
#
inputs = torch . tensor( [ [ 0.0 ] , [ 1.0 ] ] )
#
print( inputs )
#
# Out:
# tensor([[0.],
#         [1.]])

# %%
weights = (-1,1)
learning_rate = 0.1

model = nn.Sequential(
    nn.Linear(1, 1, bias=True),
    nn.Sigmoid()
)

lossTimeX = []
lossTimeY = []

# with torch.no_grad():
#     model[0].weight.fill_(weights[1])
#     model[0].bias.fill_(weights[0])
#     print(model(inputs))

outputs = torch.tensor([[1], [0]])

loss_fn = nn.MSELoss(reduction='sum')

optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

for epoch in range(10000):
    loss = loss_fn(model(inputs), outputs.float())
    if epoch % 100 == 0:
        print(epoch, loss.item())
        print("Item loss:",loss.item())

    optimizer.zero_grad()

    loss.backward()
#     with torch.no_grad():
#         for param in model.parameters():
#             print(param.grad)
    optimizer.step()
#     print("After step")
#     with torch.no_grad():
#         for param in model.parameters():
#             print(param.grad)
# Out:
# 0 0.5729255080223083
# Item loss: 0.5729255080223083
# 100 0.1799175888299942
# Item loss: 0.1799175888299942
# 200 0.1009596735239029
# Item loss: 0.1009596735239029
# 300 0.06685557961463928
# Item loss: 0.06685557961463928
# 400 0.04889601469039917
# Item loss: 0.04889601469039917
# 500 0.038099728524684906
# Item loss: 0.038099728524684906
# 600 0.030995849519968033
# Item loss: 0.030995849519968033
# 700 0.026010069996118546
# Item loss: 0.026010069996118546
# 800 0.022338837385177612
# Item loss: 0.022338837385177612
# 900 0.019533872604370117
# Item loss: 0.019533872604370117
# 1000 0.01732712984085083
# Item loss: 0.01732712984085083
# 1100 0.01554948277771473
# Item loss: 0.01554948277771473
# 1200 0.014089261181652546
# Item loss: 0.014089261181652546
# 1300 0.012869970872998238
# Item loss: 0.012869970872998238
# 1400 0.011837628670036793
# Item loss: 0.011837628670036793
# 1500 0.010953022167086601
# Item loss: 0.010953022167086601
# 1600 0.010187109000980854
# Item loss: 0.010187109000980854
# 1700 0.009517913684248924
# Item loss: 0.009517913684248924
# 1800 0.008928457275032997
# Item loss: 0.008928457275032997
# 1900 0.008405540138483047
# Item loss: 0.008405540138483047
# 2000 0.007938658818602562
# Item loss: 0.007938658818602562
# 2100 0.007519411854445934
# Item loss: 0.007519411854445934
# 2200 0.007140954490751028
# Item loss: 0.007140954490751028
# 2300 0.006797708570957184
# Item loss: 0.006797708570957184
# 2400 0.0064850435592234135
# Item loss: 0.0064850435592234135
# 2500 0.006199111230671406
# Item loss: 0.006199111230671406
# 2600 0.00593667384237051
# Item loss: 0.00593667384237051
# 2700 0.005694973282516003
# Item loss: 0.005694973282516003
# 2800 0.005471690092235804
# Item loss: 0.005471690092235804
# 2900 0.005264811683446169
# Item loss: 0.005264811683446169
# 3000 0.005072613246738911
# Item loss: 0.005072613246738911
# 3100 0.004893622361123562
# Item loss: 0.004893622361123562
# 3200 0.0047265393659472466
# Item loss: 0.0047265393659472466
# 3300 0.004570208489894867
# Item loss: 0.004570208489894867
# 3400 0.004423652775585651
# Item loss: 0.004423652775585651
# 3500 0.004285998642444611
# Item loss: 0.004285998642444611
# 3600 0.00415645819157362
# Item loss: 0.00415645819157362
# 3700 0.004034343175590038
# Item loss: 0.004034343175590038
# 3800 0.003919034730643034
# Item loss: 0.003919034730643034
# 3900 0.003810002002865076
# Item loss: 0.003810002002865076
# 4000 0.003706742310896516
# Item loss: 0.003706742310896516
# 4100 0.003608801867812872
# Item loss: 0.003608801867812872
# 4200 0.0035158097743988037
# Item loss: 0.0035158097743988037
# 4300 0.0034273869823664427
# Item loss: 0.0034273869823664427
# 4400 0.00334320985712111
# Item loss: 0.00334320985712111
# 4500 0.0032629810739308596
# Item loss: 0.0032629810739308596
# 4600 0.0031864428892731667
# Item loss: 0.0031864428892731667
# 4700 0.003113340586423874
# Item loss: 0.003113340586423874
# 4800 0.003043455071747303
# Item loss: 0.003043455071747303
# 4900 0.0029765707440674305
# Item loss: 0.0029765707440674305
# 5000 0.00291251577436924
# Item loss: 0.00291251577436924
# 5100 0.002851094352081418
# Item loss: 0.002851094352081418
# 5200 0.002792172133922577
# Item loss: 0.002792172133922577
# 5300 0.0027355824131518602
# Item loss: 0.0027355824131518602
# 5400 0.002681202022358775
# Item loss: 0.002681202022358775
# 5500 0.0026289045345038176
# Item loss: 0.0026289045345038176
# 5600 0.002578574465587735
# Item loss: 0.002578574465587735
# 5700 0.00253009470179677
# Item loss: 0.00253009470179677
# 5800 0.0024833730421960354
# Item loss: 0.0024833730421960354
# 5900 0.0024383235722780228
# Item loss: 0.0024383235722780228
# 6000 0.0023948457092046738
# Item loss: 0.0023948457092046738
# 6100 0.0023528572637587786
# Item loss: 0.0023528572637587786
# 6200 0.0023123016580939293
# Item loss: 0.0023123016580939293
# 6300 0.00227308738976717
# Item loss: 0.00227308738976717
# 6400 0.0022351627703756094
# Item loss: 0.0022351627703756094
# 6500 0.0021984665654599667
# Item loss: 0.0021984665654599667
# 6600 0.002162925899028778
# Item loss: 0.002162925899028778
# 6700 0.0021285051479935646
# Item loss: 0.0021285051479935646
# 6800 0.002095138654112816
# Item loss: 0.002095138654112816
# 6900 0.0020627910271286964
# Item loss: 0.0020627910271286964
# 7000 0.0020314096473157406
# Item loss: 0.0020314096473157406
# 7100 0.0020009533036500216
# Item loss: 0.0020009533036500216
# 7200 0.0019713812507689
# Item loss: 0.0019713812507689
# 7300 0.0019426601938903332
# Item loss: 0.0019426601938903332
# 7400 0.0019147455459460616
# Item loss: 0.0019147455459460616
# 7500 0.001887607155367732
# Item loss: 0.001887607155367732
# 7600 0.0018612237181514502
# Item loss: 0.0018612237181514502
# 7700 0.0018355533247813582
# Item loss: 0.0018355533247813582
# 7800 0.001810572575777769
# Item loss: 0.001810572575777769
# 7900 0.0017862460808828473
# Item loss: 0.0017862460808828473
# 8000 0.0017625570762902498
# Item loss: 0.0017625570762902498
# 8100 0.0017394793685525656
# Item loss: 0.0017394793685525656
# 8200 0.0017169887432828546
# Item loss: 0.0017169887432828546
# 8300 0.0016950687859207392
# Item loss: 0.0016950687859207392
# 8400 0.0016736926045268774
# Item loss: 0.0016736926045268774
# 8500 0.0016528326086699963
# Item loss: 0.0016528326086699963
# 8600 0.0016324843745678663
# Item loss: 0.0016324843745678663
# 8700 0.0016126256668940187
# Item loss: 0.0016126256668940187
# 8800 0.001593228429555893
# Item loss: 0.001593228429555893
# 8900 0.0015742944087833166
# Item loss: 0.0015742944087833166
# 9000 0.0015557948499917984
# Item loss: 0.0015557948499917984
# 9100 0.001537724630907178
# Item loss: 0.001537724630907178
# 9200 0.001520058372989297
# Item loss: 0.001520058372989297
# 9300 0.0015027865301817656
# Item loss: 0.0015027865301817656
# 9400 0.001485900254920125
# Item loss: 0.001485900254920125
# 9500 0.0014693858101963997
# Item loss: 0.0014693858101963997
# 9600 0.0014532275963574648
# Item loss: 0.0014532275963574648
# 9700 0.001437413739040494
# Item loss: 0.001437413739040494
# 9800 0.001421942375600338
# Item loss: 0.001421942375600338
# 9900 0.0014067885931581259
# Item loss: 0.0014067885931581259

# %%
with torch.no_grad():
    for param in model.parameters():
        print(param)
# Out:
# Parameter containing:
# tensor([[-7.2381]], requires_grad=True)
# Parameter containing:
# tensor([3.5132], requires_grad=True)
