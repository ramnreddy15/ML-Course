# %%
import matplotlib.pyplot as plt
import numpy as np

file = open("./data.csv")
csvFile = np.loadtxt(file, delimiter=",", skiprows=0)
n = csvFile.shape[0]
X1 = csvFile[:,0]
Y1 = csvFile[:,1]
marker = csvFile[:,2]
X2 = X1[12:]
X1 = X1[:12]
Y2 = Y1[12:]
Y1 = Y1[:12]
fig , ax = plt . subplots()
sc = ax . scatter( X1 , Y1 , color='blue', s = 20 , linewidths = 1, marker='o', label="0")
sc = ax . scatter( X2 , Y2 , color='red', s = 20 , linewidths = 1, marker='X', label="1")
sc . set_facecolor( 'none' )
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title("X-axis vs. Y-Axis")
ax.legend()
