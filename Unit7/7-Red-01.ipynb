# %%
#
import torch
import torch.nn as nn
import math
#
inputs = torch . tensor( [ [ 0.0, 0 ] , [ 1.0,1 ], [1,0], [0,1] ] )
#
print( inputs )
#
# Out:
# tensor([[0., 0.],
#         [1., 1.],
#         [1., 0.],
#         [0., 1.]])

# %%
weights = (-1,1)
learning_rate = 0.1

model = nn.Sequential(
    nn.Linear(2, 1, bias=True),
    nn.Sigmoid()
)

outputs = torch.tensor([[0], [1], [0], [0]])

loss_fn = nn.MSELoss(reduction='sum')

model.zero_grad()

optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

with torch.no_grad():
    for param in model.parameters():
        print(param)

for epoch in range(10000):
    loss = loss_fn(model(inputs), outputs.float())
    optimizer.zero_grad()

    loss.backward()
    optimizer.step()
print()
with torch.no_grad():
    for param in model.parameters():
        print(param)
        
print()
print(loss.item())
# Out:
# Parameter containing:
# tensor([[-0.3483, -0.2330]], requires_grad=True)
# Parameter containing:
# tensor([-0.4066], requires_grad=True)
#
# Parameter containing:
# tensor([[6.2714, 6.2714]], requires_grad=True)
# Parameter containing:
# tensor([-9.4970], requires_grad=True)
#
# 0.00498216412961483

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
    
fig = plt.figure()
ax = plt.axes(projection='3d')

X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)
Z = np.zeros(X.shape)
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        Z[i][j] = model(torch . tensor([float(X[i][j]),float(Y[i][j])]))

print(Z.shape)

ax.plot_wireframe(X, Y, Z, linewidth=0.01, antialiased=False)

ax.set_zlim(0, 1)

plt.show()
# Out:
# (100, 100)

# %%
#
import torch
import torch.nn as nn
import math
#
inputs = torch . tensor( [ [ 0.0, 0 ] , [ 1.0,1 ], [1,0], [0,1] ] )
#
print( inputs )
#
# Out:
# tensor([[0., 0.],
#         [1., 1.],
#         [1., 0.],
#         [0., 1.]])

# %%
weights = (-1,1)
learning_rate = 0.1

model = nn.Sequential(
    nn.Linear(2, 1, bias=True),
    nn.Sigmoid()
)

outputs = torch.tensor([[0], [1], [1], [1]])

loss_fn = nn.MSELoss(reduction='sum')

model.zero_grad()

optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

with torch.no_grad():
    for param in model.parameters():
        print(param)

for epoch in range(10000):
    loss = loss_fn(model(inputs), outputs.float())
    optimizer.zero_grad()

    loss.backward()
    optimizer.step()
print()
with torch.no_grad():
    for param in model.parameters():
        print(param)
        
print()
print(loss.item())
# Out:
# Parameter containing:
# tensor([[ 0.6085, -0.2675]], requires_grad=True)
# Parameter containing:
# tensor([0.6730], requires_grad=True)
#
# Parameter containing:
# tensor([[6.9522, 6.9522]], requires_grad=True)
# Parameter containing:
# tensor([-3.2355], requires_grad=True)
#
# 0.00255978642962873

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
    
fig = plt.figure()
ax = plt.axes(projection='3d')

X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)
Z = np.zeros(X.shape)
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        Z[i][j] = model(torch . tensor([float(X[i][j]),float(Y[i][j])]))

print(Z.shape)

ax.plot_wireframe(X, Y, Z, linewidth=0.01, antialiased=False)

ax.set_zlim(0, 1)

plt.show()
# Out:
# (100, 100)
