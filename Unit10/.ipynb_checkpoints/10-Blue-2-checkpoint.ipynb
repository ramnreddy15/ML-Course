# %%
from PIL import Image

# %%
img = Image.open('/cluster/2023rreddy/ML-Course/Unit10/images/ps3s.png', 'r')
red, green, blue, alpha = img.split()
img.putalpha(alpha)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=258x167 at 0x7FF589179EB0>
